# %% [markdown]
# # **Curso de Python - Módulo Básico**
# Curso ofertado a partir da parceria entre o Centro Estadual de Educação Tecnológica Paula Souza – CEETEPS, por intermédio da Fatec Sorocaba e Fatec Jundiaí e a Huawei do Brasil, com interveniência da Fundação para Desenvolvimento da UNESP – FUNDUNESP.

# %% [markdown]
# # **Capítulo 2 - Classes e Objetos**

# %% [markdown]
# **Exemplo 2.1**<br>
# Variáveis: qte, puni, ptot e msg

# %%
qtde = 2
preco_unitario = 36.90
preco_total = qtde * preco_unitario
msg = 'Total ='
print(msg, preco_total)
# Out:
# Total = 73.8

# %% [markdown]
# **Exemplo 2.2**<br>
# Função type para mostrar a classe (int, float, str).

# %%
qtde = 2
type(qtde)
# Out:
# int

# %%
preco_unitario = 36.9
type(preco_unitario)
# Out:
# float

# %%
preco_total = qtde * preco_unitario
type(preco_total)
# Out:
# float

# %%
msg = 'Total ='
type(msg)
# Out:
# str

# %% [markdown]
# **Exemplo 2.3**<br>
# Objetos simples: int, float, complex, bool e None

# %%
n = 12
type(n)
# Out:
# int

# %%
f = 7.38
type(f)
# Out:
# float

# %%
c = 1.57 + 3.17j
type(c)
# Out:
# complex

# %%
b = True
type(b)
# Out:
# bool

# %%
x = None
type(x)
# Out:
# NoneType

# %% [markdown]
# **Exemplo 2.5**<br>
# Função type e id

# %%
obj1 = 10
type(obj1)
# Out:
# int

# %%
id(obj1)
# Out:
# 11645640

# %%
obj2 = 10
id(obj2)
# Out:
# 11645640

# %%
obj3 = 10.0
type(obj3)
# Out:
# float

# %%
id(obj3)
# Out:
# 132626871367120

# %% [markdown]
# **Exemplo 2.6**

# %%
x = 50
y = 12 + 38
z = 100 - 50

# %%
id(x)
# Out:
# 11646920

# %%
id(y)
# Out:
# 11646920

# %%
id(z)
# Out:
# 11646920

# %%
print(x, y, z)
# Out:
# 50 50 50

# %%
z = 90
id(z)
# Out:
# 11648200

# %% [markdown]
# **Exemplo 2.7**

# %% [markdown]
# Parte 1 - Exemplo usando número inteiro

# %%
obj1 = 8
id(obj1)
# Out:
# 11645576

# %%
obj1 = 12
id(obj1)
# Out:
# 11645704

# %% [markdown]
# Parte 2 - Exemplo usando uma lista

# %%
L = [44, 17, 26, 35, 20]
id(L)
# Out:
# 132626868952768

# %%
L[0] = 12
print(L)
# Out:
# [12, 17, 26, 35, 20]

# %%
id(L)
# Out:
# 132626868952768

# %% [markdown]
# **Exemplo 2.8**

# %%
A = 14
B = 5
C = A + B
print(C)
# Out:
# 19

# %%
C = A - B
print(C)
# Out:
# 9

# %%
C = A * B
print(C)
# Out:
# 70

# %%
C = A / B # Resultado real
print(C)
# Out:
# 2.8

# %%
C = A // B # Resultado inteiro (quociente)
print(C)
# Out:
# 2

# %%
C = A % B # Resto da divisão
print(C)
# Out:
# 4

# %%
C = -A
print(C)
# Out:
# -14

# %%
C = A ** B # Eleva A por B
print(C)
# Out:
# 537824

# %% [markdown]
# **Exercício proposto**

# %%
A = 10
B = 25
C = 7

# %%
R = 2 * A + B
print(R)
# Out:
# 45

# %%
R = 2 * (A + B)
print(R)
# Out:
# 70

# %%
X = (A + B) / (A + C)
print(X)
# Out:
# 2.0588235294117645

# %%
X = (2 * B - C) / (2 * A)
print(X)
# Out:
# 2.15

# %%
X = -A * 2 + B
print(X)
# Out:
# 5

# %%
X = A % B * C
print(X)
# Out:
# 70

# %% [markdown]
# **Exemplo 2.9**

# %%
A = 10
P = 4
A += P
print(A)
# Out:
# 14

# %%
A = 0
A += 15
print(A)
# Out:
# 15

# %%
A -= 10 # 15 - 10
print(A)
# Out:
# 5

# %%
A *= 6 # 5 x 6
print(A)
# Out:
# 30

# %%
A /= 4 # 30 : 4
print(A)
# Out:
# 7.5

# %% [markdown]
# **Exemplo 2.10**

# %%
from math import sqrt
X = 49
R = sqrt(X) # raiz quadrada de X
print(R)
# Out:
# 7.0
