# %% [markdown]
# # **Curso de Python - Módulo Básico**
# Curso ofertado a partir da parceria entre o Centro Estadual de Educação Tecnológica Paula Souza – CEETEPS, por intermédio da Fatec Sorocaba e Fatec Jundiaí e a Huawei do Brasil, com interveniência da Fundação para Desenvolvimento da UNESP – FUNDUNESP.

# %% [markdown]
# # **Capítulo 3 - Comandos de saída e entrada**

# %% [markdown]
# **Exemplo 3.1**

# %%
# Caso 1
print('Esta é uma mensagem exemplo.')
# Out:
# Esta é uma mensagem exemplo.

# %%
# Caso 2
X = 26
print(X)
Y = 58
print(Y)
print(X, Y)
# Out:
# 26
# 58
# 26 58

# %%
# Caso 3
print('Valor de X =', X)
# Out:
# Valor de X = 26

# %%
# Caso 4
print('Valores: X = {0} e Y = {1}'.format(X, Y)) # Marcadores {0} e {1}; método .format e objetos que serão apresentados (X, Y)
# Out:
# Valores: X = 26 e Y = 58

# %% [markdown]
# **Exemplos de formatação de strings**

# %%
A = 9
X = 4.86

# %%
S = "Dado = {:d}".format(A) # d - número inteiro, em base 10
print(S)
# Out:
# Dado = 9

# %%
S = "Dado = {:5d}".format(A) # 5d - número inteiro ocupando no mínimo 5 caracteres alinhado à direita
print(S)
# Out:
# Dado =     9

# %%
S = "Dado = {:f}".format(X) # f - número real, exibindo o padrão de 6 casas após a vírgula
print(S)
# Out:
# Dado = 4.860000

# %%
S = "Dado = {:7.3f}".format(X) # f - número real, ocupando no mínimo 7 caracteres e exibindo 3 casas após a vírgula
print(S)
# Out:
# Dado =   4.860

# %%
S = "Dado = {:.2f}".format(X) # f - número real, exibindo 2 casas após a vírgula
print(S)
# Out:
# Dado = 4.86

# %%
S = "..{:>7d}..".format(A) # 7d - número inteiro ocupando no mínimo 7 caracteres alinhado à direita (caractere de posição >)
print(S)
# Out:
# ..      9..

# %%
S = "..{:<7d}..".format(A) # 7d - número inteiro ocupando no mínimo 7 caracteres alinhado à esquerda (caractere de posição <)
print(S)
# Out:
# ..9      ..

# %%
S = "..{:^7d}..".format(A) # 7d - número inteiro ocupando no mínimo 7 caracteres centralizado (caractere de posição ^)
print(S)
# Out:
# ..   9   ..

# %% [markdown]
# **Exemplo 3.4**

# %%
A = 14
B = 32

# %%
s1 = "Valores: A é {} e B é {}.".format(A, B)
print(s1)
# Out:
# Valores: A é 14 e B é 32.

# %%
s2 = f"Valores: A é {A} e B é {B}."
print(s2)
# Out:
# Valores: A é 14 e B é 32.

# %% [markdown]
# **Exemplo 3.5**

# %%
A = input()
print(A)
# Out:
# Digitei isto
# Digitei isto

# %%
B = input('Digite algo: ')
print(B)
# Out:
# Digite algo: Digitei isto
# Digitei isto

# %% [markdown]
# **Exemplo 3.6**

# %%
N = input('Digite um número inteiro: ')
print(N)
type(N)
# Out:
# Digite um número inteiro: 37
# 37
# str

# %%
F = input('Digite um número real: ')
print(F)
type(F)
# Out:
# Digite um número real: 31.47
# 31.47
# str

# %%
R = N + F # concatenação das strings
print(R)
# Out:
# 3731.47

# %%
N = int(N) # converte N para inteiro
F = float(F) # converte F para real
R = N + F
print(R)
# Out:
# 68.47

# %% [markdown]
# **Exemplo 3.7**

# %%
x = '19' # x recebe o string '19'
type(x) # conferindo a classe de x
# Out:
# str

# %%
a = int(x) # a recebe o retorno da conversão de x para inteiro
type(a) # conferindo a classe de a
# Out:
# int

# %%
x = '3.75' # x recebe o string '3.75'
type(x) # conferindo a classe de x
# Out:
# str

# %%
r = float(x) # r recebe o retorno da conversão de x para real
type(r) # conferindo a classe de r
# Out:
# float

# %%
b = a + r # soma um int com um float, produzindo um float em b
print(b)
# Out:
# 22.75

# %%
x = str(b) # converte o float em b para string
print(x)
type(x)
# Out:
# 22.75
# str

# %% [markdown]
# **Exercício Proposto 3.1**<br>
# Enunciado: Escreva um programa que leia os nomes de três pessoas de uma família: mãe, pai e criança. O programa deve exibir na tela a mensagem.
# "Os adultos {mãe} e {pai} são os responsáveis por {criança}"
# Faça de dois modos: com o método .format() e com f-string

# %%
mae = input('Digite o nome da mãe: ')
pai = input('Digite o nome do pai: ')
crianca = input('Digite o nome da criança: ')

print('\nSaída usando o método format:')
print("Os adultos {0} e {1} são os responsáveis por {2}.".format(mae, pai, crianca))

print('\nSaída usando o método f-string:')
print(f"Os adultos {mae} e {pai} são os responsáveis por {crianca}.")
# Out:
# Digite o nome da mãe: Joana
# Digite o nome do pai: João
# Digite o nome da criança: Juca
#
# Saída usando o método format:
# Os adultos Joana e João são os responsáveis por Juca.
#
# Saída usando o método f-string:
# Os adultos Joana e João são os responsáveis por Juca.

# %% [markdown]
# **Exercício Proposto 3.2**<br>
# Enunciado: Escreva um programa que leia um texto e mostre na tela o texto e a quantidade de caracteres que ele contém, usando a seguinte mensagem:<br>
# "O texto {AquiColoqueOTexto} contém {Quantidade} caracteres"<br>
# Faça de dois modos: com o método .format() e com f-string<br>
# Dica: Use a função len()

# %%
texto = input('Digite um texto: ')
quantidade = len(texto)

print('\nSaída usando o método format:')
print("O texto {0} contém {1} caracteres.".format(texto, quantidade))

print('\nSaída usando o método f-string:')
print(f"O texto {texto} contém {quantidade} caracteres.")
# Out:
# Digite um texto: Diego
#
# Saída usando o método format:
# O texto Diego contém 5 caracteres.
#
# Saída usando o método f-string:
# O texto Diego contém 5 caracteres.

# %% [markdown]
# **Exercício Proposto 3.3**<br>
# Enunciado: Escreva um programa que leia três números reais em objetos denominados A, B e C. O programa deve calcular e mostrar na tela os resultados das fórmulas a seguir, usando 3 casas decimais.<br>
# R1 = A + B + C<br>
# R2 = A.B.C<br>
# R3 = 2.(A+B)-C<br>
# R4 = (A + B + C)/3<br>
# R5 = (2B + 3C)/5A<br>
# R6 = A² + B²<br>
# Para testar seu programa considere: A = 22.65   B = –39.1   C = 18.115<br>
# R1 = 1.665<br>
# R2 = –16042.916<br>
# R3 = –51.015<br>
# R4 = 0.555<br>
# R5 = –0.211<br>
# R6 = 2041.832<br>

# %%
A = float(input('Digite o valor de A: '))
B = float(input('Digite o valor de B: '))
C = float(input('Digite o valor de C: '))
R1 = A + B + C
print(f"R1 = {R1:.3f}")

R2 = A * B * C
print(f"R2 = {R2:.3f}")

R3 = (2 * (A + B)) - C
print(f"R3 = {R3:.3f}")

R4 = (A + B + C)/3
print(f"R4 = {R4:.3f}")

R5 = (2 * B + 3 * C)/(5 * A)
print(f"R5 = {R5:.3f}")

R6 = A ** 2 + B ** 2
print(f"R6 = {R6:.3f}")
# Out:
# Digite o valor de A: 22.65
# Digite o valor de B: -39.1
# Digite o valor de C: 18.115
# R1 = 1.665
# R2 = -16042.916
# R3 = -51.015
# R4 = 0.555
# R5 = -0.211
# R6 = 2041.832

# %% [markdown]
# **Exercício Proposto 3.4**<br>
# Enunciado: Escreva um programa que leia um número real e mostre na tela os valores de 25%, 50%, 75% do valor lido usando o formato com 3 casas decimais mostrado abaixo:<br>
# Exemplo: Valor lido: 136.7<br>
# Exibir: 25% -> 34.175 - 50% -> 68.350 - 75% -> 102.525

# %%
numero = float(input('Digite um número real: '))
print(f'25% -> {numero*0.25:.3f} - 50% -> {numero*0.5:.3f} - 75% -> {numero*0.75:.3f}')
# Out:
# Digite um número real: 136.7
# 25% -> 34.175 - 50% -> 68.350 - 75% -> 102.525

# %% [markdown]
# **Exercício Proposto 3.5**<br>
# Enunciado: Escreva um programa que leia um número inteiro que representa uma quantidade de tempo em segundos. Calcule e mostre na tela a quantidade de horas, minutos e segundos.<br>
# Dicas: Leve em consideração que 1 hora tem 3600 segundos e 1 minuto tem 60 segundos. Use os operadores de divisão de inteiros (//) e resto (%).<br>
# Exemplos:<br>
# | Entrada (segundos) | Saída|
# | :---: | :---: |
# | 1 | 0 hora(s), 0 minuto(s), 1 segundo(s)|
# | 38 | 0 hora(s), 0 minuto(s), 38 segundo(s)|
# | 746 | 0 hora(s), 12 minuto(s), 26 segundo(s)|
# | 4578 | 1 hora(s), 16 minuto(s), 18 segundo(s)|
# | 73551 | 20 hora(s), 25 minuto(s), 51 segundo(s)|
# <br>

# %%
tempo = int(input("Digite o tempo em segundos: "))
hora = tempo // 3600
tempo = tempo % 3600
minuto = tempo // 60
segundo = tempo % 60
print(f'{hora} hora(s), {minuto} minuto(s), {segundo} segundo(s)')
# Out:
# Digite o tempo em segundos: 73551
# 20 hora(s), 25 minuto(s), 51 segundo(s)

# %% [markdown]
# **Exercício Proposto 3.6**<br>
# Enunciado: Uma empresa comercial trabalha com 3 vendedores externos e os remunera com R$ 1200,00 fixos mais comissão de 6% sobre o valor total vendido no mês. Escreva um programa que leia o nome e o total vendido pelos 3 vendedores, calcule e exiba na tela a mensagem de saída conforme o exemplo a seguir. Exiba os valores numéricos com duas casas decimais.<br>
# Exemplo de saída:<br>
#
# *   vendedor José Carlos Santos vendeu R$\\$$ 43759.35 e faz jus a uma comissão de R$\\$$ 3825.56
# *   vendedor Manoel Guimarães vendeu R$\\$$ 61417.81 e faz jus a uma comissão de R$\\$$ 4885.07
# *   vendedor Plínio Pereira vendeu R$\\$$ 39336.87 e faz jus a uma comissão de R$\\$$ 3560.21

# %%
vendedor1 = input('Digite o nome do primeiro vendedor: ')
venda1 = float(input('Digite o valor da venda: '))
comissao1 = (venda1 * 0.06) + 1200

vendedor2 = input('Digite o nome do segundo vendedor: ')
venda2 = float(input('Digite o valor da venda: '))
comissao2 = (venda2 * 0.06) + 1200

vendedor3 = input('Digite o nome do terceiro vendedor: ')
venda3 = float(input('Digite o valor da venda: '))
comissao3 = (venda3 * 0.06) + 1200

print(f'vendedor {vendedor1} vendeu R$ {venda1} e faz jus a uma comissão de R$ {comissao1:.2f}.')
print(f'vendedor {vendedor2} vendeu R$ {venda2} e faz jus a uma comissão de R$ {comissao2:.2f}.')
print(f'vendedor {vendedor3} vendeu R$ {venda3} e faz jus a uma comissão de R$ {comissao3:.2f}.')
# Out:
# Digite o nome do primeiro vendedor: José Carlos Santos
# Digite o valor da venda: 43759.35
# Digite o nome do segundo vendedor: Manoel Guimarães
# Digite o valor da venda: 61417.81
# Digite o nome do terceiro vendedor: Plínio Pereira
# Digite o valor da venda: 39336.87
# vendedor José Carlos Santos vendeu R$ 43759.35 e faz jus a uma comissão de R$ 3825.56.
# vendedor Manoel Guimarães vendeu R$ 61417.81 e faz jus a uma comissão de R$ 4885.07.
# vendedor Plínio Pereira vendeu R$ 39336.87 e faz jus a uma comissão de R$ 3560.21.

# %% [markdown]
# **Exercício Proposto 3.7**<br>
# Enunciado: Quando uma pessoa ou uma empresa realiza um investimento espera-se um retorno positivo (lucro), embora também possa ocorrer um retorno negativo (prejuízo). Uma forma inicial de avaliar o retorno é conhecida com Retorno sobre Investimento (ou ROI, uma sigla em inglês). Cálculo do ROI:<br>
# ROI = ((Receita - (Custos + Investimento))/(Custos + Investimento)).100%<br>
#
# Escreva um programa que leia 3 dados de entrada reais: Investimento, Custos e Receita, calcule o ROI usando a fórmula acima e exiba o resultado com uma casa decimal no formato mostrado abaixo.<br>
# Exemplo: Investimento = 2300.00 – Custos = 345.73 – Receita = 2712,17<br>
# Saída: ROI = 2.5%<br>
# Outros testes:
# | Investimento | Custos | Receita | ROI |
# | :---: | :---: | :---: | :---: |
# | 22500.00 | 535.83 | 25419.61 | 10.3% |
# | 15000.00 | 419.35 | 14403.44 | -6.6% |
# | 18000.00 | 837.40 | 19132.28 | 1.6% |

# %%
investimento = float(input('Digite o valor do investimento: '))
custos = float(input('Digite o valor dos custos: '))
receita = float(input('Digite o valor da receita: '))
ROI = ((receita - (custos + investimento))/(custos + investimento))*100
print(f'{ROI:.1f}%')
# Out:
# Digite o valor do investimento: 15000
# Digite o valor dos custos: 419.35
# Digite o valor da receita: 14403.44
# -6.6%
